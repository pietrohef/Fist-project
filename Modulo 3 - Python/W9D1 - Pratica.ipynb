# %% [markdown]
# # ESERCIZIO 1
# ## Fare la speza

# %%
#1. Controllare cosa manca in casa
#2. Scrivere la lista della spesa
#3. Recarsi al supermercato
#4. Prendere un carrello o un cestino
#5. Cercare ogni prodotto della lista tra gli scaffali
#6. Mettere i prodotti nel carrello
#7. Recarsi alla cassa
#8. Pagare
#9. Tornare a casa e riporre i prodotti

# %%
lista_spesa = ("pomodori","lattuga","patate","limone","carne")

# %%
print("lista della spesa = ",lista_spesa)
# Out:
# lista della spesa =  ('pomodori', 'lattuga', 'patate', 'limone', 'carne')

# %%
type(lista_spesa)
# Out:
# tuple

# %% [markdown]
# ## Studiare un concetto

# %%
#1. Scegliere il concetto da studiare
#2. Raccogliere il materiale necessario (libro, appunti, slides)
#3. Leggere il materiale una prima volta per avere una visione generale
#4. Rileggere con attenzione e prendere appunti
#5. Schematizzare i punti chiave (mappa concettuale o schema)
#6. Ripetere il concetto a voce alta o per iscritto
#7. Verificare la comprensione con domande o esercizi
#8. Ripassare dopo qualche ora o il giorno successivo

# %% [markdown]
# ## Riempire il serbatoio dell'auto

# %%
#Riempire il serbatoio dell'auto
#1. Verificare che il serbatoio sia quasi vuoto
#2. Cercare un distributore di benzina nelle vicinanze
#3. Recarsi al distributore
#4. Accostare l'auto al distributore corretto (tipo di carburante)
#5. Spegnere il motore
#6. Aprire il tappo del serbatoio
#7. Inserire la pistola erogatrice nel serbatoio
#8. Selezionare la quantità o fare "pieno"
#9. Attendere il completamento dell'erogazione
#10. Rimuovere la pistola e richiudere il tappo
#11. Pagare (in cassa o al self-service)
#12. Riprendere la marcia

# %%
capacita_serbatoio = 40
print(capacita_serbatoio)

livello_acttuale_serbatoio = 8
print(livello_acttuale_serbatoio)

prezzo = 1.75
print(unita_di_misura)
# Out:
# 40
# 8
# litri

# %%
quantità_mancante = capacita_serbatoio - livello_acttuale_serbatoio
print(quantità_mancante,"litri")
# Out:
# 32 litri

# %%
costo = quantità_mancante * prezzo
print(costo,"euros")
# Out:
# 56.0 euros

# %% [markdown]
# ## Acquistare uno snack al distributore automatico

# %%
#1. Avvicinarsi al distributore automatico
#2. Controllare i prodotti disponibili e i relativi codici
#3. Scegliere lo snack desiderato
#4. Verificare di avere il denaro o la carta necessari
#5. Inserire monete, banconote o carta di pagamento
#6. Digitare il codice del prodotto scelto
#7. Attendere che il prodotto venga erogato
#8. Prelevare lo snack dallo sportello di uscita
#9. Ritirare l'eventuale resto

# %% [markdown]
# # ESERCIZIO 2

# %%
Studenti = 25
print(Studenti)
type(Studenti)
# Out:
# 25
# int

# %%
Studenti_arrivati = 3

# %%
Totali_studenti = Studenti + Studenti_arrivati

# %%
print(Totali_studenti)
# Out:
# 28

# %%
type(Totali_studenti)
# Out:
# int

# %% [markdown]
# # ESERCIZIO 3

# %%
stringa_1 = "Epicode " #Creare una variabile che contiene la stringa "Epicode", quindi stamparla a video

# %%
stringa_2 = "Top" #Creare la variabile che contiene la stringa "Top"

# %%
stinga_1 + stringa_2 #quindi concatenare con l’operatore + le due variabili
# Out:
# 'EpicodeTop'

# %%
print(stringa_1)
print(stringa_2)
# Out:
# Epicode
# Top

# %%
print(type(stringa_1))
print(type(stringa_2)) #Stampare a video i loro datatypes
# Out:
# <class 'str'>
# <class 'str'>

# %%
print(stringa_1 * 5) #Stampare la prima variabile 5 volte utilizzando l’operatore *
# Out:
# Epicode Epicode Epicode Epicode Epicode

# %% [markdown]
# # ESERCIZIO 4

# %%
x1= 10
y2= 2
z3= 3
print(x1)
print(y2)
print(z3)
# Out:
# 10
# 2
# 3

# %%
T_variabile = (x1+y2)*z3

# %%
print(T_variabile)
# Out:
# 36

# %% [markdown]
# # ESERCIZIO 5

# %%
strl1 = "Windows"
strl2 = "Excel"
strl3 = "Powerpoint"
strl4 = "Word"
print(strl1)
print(strl2)
print(strl3)
print(strl4)
#Creiamo le seguenti stringhe
#Per ognuna di esse stampiamo a video
# Out:
# Windows
# Excel
# Powerpoint
# Word

# %%
print(len(strl1))
print(len(strl2))
print(len(strl3))
print(len(strl4))
#la lunghezza con la funzione len()
# Out:
# 7
# 5
# 10
# 4

# %% [markdown]
# # ESERCIZIO 6

# %%
anno = 356

# %%
giorno = 24

# %%
ora = 60

# %%
secondi = 60

# %%
secondi_x_anno = (((secondi*ora)*giorno)*anno)

# %%
print(secondi_x_anno)
# Out:
# 30758400

# %% [markdown]
# # ESERCIZIO 7

# %%
area = 0

# %%
perimetro = 0

# %%
base = 4
altezza = 6
print(base)
print(altezza)
# Out:
# 4
# 6

# %%
area = base * altezza
print(area)
perimetro = 2/(base + altezza)
print(perimetro)
# Out:
# 24
# 0.2

# %% [markdown]
# # ESERCIZIO 8

# %%
Prezzo = 120

# %%
sconto = Prezzo * 20/100

# %%
prezzo_scontato = Prezzo - sconto

# %%
print(prezzo_scontato)
# Out:
# 96.0

# %% [markdown]
# # ESERCIZIO 9

# %%
 message = " I am studying Python"

# %%
message_maiuscolo = message.upper()

# %%
print(message_maiuscolo)
# Out:
#  I AM STUDYING PYTHON

# %%
message_minuscolo = message.lower()

# %%
print(message_minuscolo)
# Out:
#  i am studying python

# %%
nuovo_message = message.replace("Python","lot")

# %%
print(nuovo_message)
# Out:
#  I am studying lot

# %%
Parole = message.split()

# %% [markdown]
# print(Parole)

# %%
print(len(message))
# Out:
# 21

# %% [markdown]
# # ESERCIZIO 10

# %%
Spesa = ["caffè","pane","mele","uova"]
print(Spesa)
# Out:
# ['caffè', 'pane', 'mele', 'uova']

# %%
Spesa.append("latte")

# %%
Spesa.append("pomodoro")

# %%
Spesa.append("rucolla")

# %%
print(Spesa)
# Out:
# ['caffè', 'pane', 'mele', 'uova', 'latte', 'pomodoro', 'rucolla']

# %% [markdown]
# # ESERCIZIO 11

# %%
auto = [ "Panda", "Golf", "Yaris", "Serie 3", "Clio", "208", "A4", "Fiesta", "Clio", "A4", "Serie 3", "Clio", "208", "Clio", "Civic", "Qashqai", "Corsa", "A4"]

# %%
print(auto)
# Out:
# ['Panda', 'Golf', 'Yaris', 'Serie 3', 'Clio', '208', 'A4', 'Fiesta', 'Clio', 'A4', 'Serie 3', 'Clio', '208', 'Clio', 'Civic', 'Qashqai', 'Corsa', 'A4']

# %%
print(len(auto)) #Quante auto ci sono in tutto?
# Out:
# 18

# %%
auto.count("Clio") #Quante "Clio" ci sono?
# Out:
# 4

# %%
auto.count("208") #Quante "208"?
# Out:
# 2

# %%
auto.count("Qashqai") #Quante "Qashqai"?
# Out:
# 1

# %%
auto.count("Cooper") #Quante "Cooper"?
# Out:
# 0

# %%
auto.count("A4") #Quante "A4"?
# Out:
# 3

# %%
auto.remove("Fiesta") #Viene venduta la "Fiesta", eliminarla dalla lista

# %%
print(auto)
# Out:
# ['Panda', 'Golf', 'Yaris', 'Serie 3', 'Clio', '208', 'A4', 'Clio', 'A4', 'Serie 3', 'Clio', '208', 'Clio', 'Civic', 'Qashqai', 'Corsa', 'A4']

# %%
print(len(auto))
# Out:
# 17

# %%
auto.sort() #Ordinare le auto in ordine alfabetico

# %%
print(auto)
# Out:
# ['208', '208', 'A4', 'A4', 'A4', 'Civic', 'Clio', 'Clio', 'Clio', 'Clio', 'Corsa', 'Golf', 'Panda', 'Qashqai', 'Serie 3', 'Serie 3', 'Yaris']

# %% [markdown]
# # ESERCIZIO 12

# %%
Minuti1 = 125
Ore1 = Minuti1 //60
Minuti_rimanenti1 = minuti % 60

# %%
print(Ore1,"ore",Minuti_rimanenti1,"minuti")
# Out:
# 2 ore 5 minuti

# %%
Minuti2 = 528
Ore2 = Minuti2 //60
Minuti_rimanenti2 = minuti % 60

# %%
print(Ore2,"ore",Minuti_rimanenti2,"minuti")
# Out:
# 8 ore 5 minuti

# %% [markdown]
# # ESERCIZIO 13

# %%
vendite = [55, 21, 42, 74, 58, 62, 73, 81, 49, 58, 19, 26]

# %%
print(vendite[1]) #prima
print(vendite[2]) #seconda
# Out:
# 21
# 42

# %%
print(vendite[10]) #penultima
print(vendite[11]) #ultima
# Out:
# 19
# 26

# %%
print(vendite[0:3])
# Out:
# [55, 21, 42]

# %%
print(vendite[2:9])
# Out:
# [42, 74, 58, 62, 73, 81, 49]

# %%
print(vendite[10:13])
# Out:
# [19, 26]

# %% [markdown]
# # ESERCIZIO 14

# %%
studenti = ["Alex", "Bob","Cindy","Dan","Emma","Faith","Grace","Henry"]
corsi = ["Cybersecurity", "Data Analyst", "Backend", "Frontend", "Data Analyst", "Backend"]

# %%
print(studenti)
print(corsi)
# Out:
# ['Alex', 'Bob', 'Cindy', 'Dan', 'Emma', 'Faith', 'Grace', 'Henry']
# ['Cybersecurity', 'Data Analyst', 'Backend', 'Frontend', 'Data Analyst', 'Backend']

# %%
corsi.append("Frontend")

# %%
corsi.append("Cybersecurity")

# %%
print(corsi)
# Out:
# ['Cybersecurity', 'Data Analyst', 'Backend', 'Frontend', 'Data Analyst', 'Backend', 'Frontend', 'Cybersecurity']
